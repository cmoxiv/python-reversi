# %%
from reversi import Board
from IPython.display import display, clear_output

from random import sample
from time import sleep

# %%
b = Board(size=26)

while not b.is_game_over():
    clear_output(wait=True)
    validMoves = list(b.legal_moves)
    mv = sample(validMoves, 1)[0]
    sleep(.01)
    b.push(mv)
    display(b)
    pass

print(b.outcome())
# Out:
# Outcome(termination=<Termination.COMPLETED: 1>, winner=white)
